# %% [markdown]
# # Module 2 — Data Types Review
#
# This notebook contains the example code from the “Data Types” instructional material.

# %% [markdown]
# ## Basic Numeric Operations

# %%
print(7 + 8)

# %% [markdown]
# ## String Concatenation

# %%
print("hello " + "world")

# %% [markdown]
# ## Mixing Types (This will cause an error)

# %%
print(7 + "8")
# this will throw an error

# %% [markdown]
# ## Checking Data Types

# %%
print(type("a"))
print(type(2))
print(type(2.5))
