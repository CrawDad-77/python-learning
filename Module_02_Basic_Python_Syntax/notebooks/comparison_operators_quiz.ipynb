# %% [markdown]
# # Comparison Operators Quiz
#
# This notebook contains practice questions on comparison operators.
# Try to answer each question **before** running the code cells.
# After you've tried, run the cells to check your answers.

# %% [markdown]
# ## Question 1
# What will each of these expressions evaluate to?
#
# Predict `True` or `False` for each:
#
# 1. `5 == 5`
# 2. `5 != 3`
# 3. `10 < 2`
# 4. `4 >= 4`
# 5. `3 <= 1`
# 6. `"cat" == "Cat"`

# %%
print(5 == 5)       # ?
print(5 != 3)       # ?
print(10 < 2)      # ?
print(4 >= 4)      # ?
print(3 <= 1)      # ?
print("cat" == "Cat")  # ?

# %% [markdown]
# ## Question 2
# Fill in the blanks so that each expression evaluates to `True`.
#
# 1. `7 __ 7`  → (use `==` or `!=`)
# 2. `3 __ 10` → (use `<` or `>`)
# 3. `4 __ 4`  → (use `>=` or `<=`)
# 4. `"apple" __ "banana"` → (use `<` or `>`)
#
# Edit the code cell to complete the comparisons, then run it.

# %%
# Edit the operators so all of these print True

print(7 == 7)          # 1
print(3 < 10)          # 2
print(4 >= 4)          # 3
print("apple" < "banana")  # 4

# %% [markdown]
# ## Question 3
# Write an expression that checks if a number `x` is **between 1 and 10 inclusive**.
#
# That means:
# - `x` is **greater than or equal to** 1
# - `x` is **less than or equal to** 10
#
# Use `and` with comparison operators.

# %%
x = 7  # Try changing this value

result = (x >= 1) and (x <= 10)
print("x is between 1 and 10:", result)

# %% [markdown]
# ## Question 4
# Compare strings and predict the results before running.
#
# 1. `"Zoo" > "apple"`
# 2. `"Alpha" < "alpha"`
# 3. `"car" <= "car"`
#
# Then run the cell.

# %%
print("Zoo" > "apple")    # ?
print("Alpha" < "alpha")  # ?
print("car" <= "car")     # ?

# %% [markdown]
# ## Question 5 – Your Turn
#
# Write three comparisons of your own:
# - One that evaluates to `True`
# - One that evaluates to `False`
# - One that uses both comparison **and** logical operators (`and` / `or`)

# %%
# 1. Should be True
print(10 > 3)

# 2. Should be False
print(5 == 2)

# 3. Comparison with logical operator
x = 15
print( (x > 10) and (x < 20) )

# %% [markdown]
# ## Summary
#
# In this quiz, you practiced:
# - Predicting the results of comparison expressions
# - Using `==`, `!=`, `<`, `>`, `<=`, `>=`
# - Combining comparisons with `and`
#
# Re-run or modify any cells until you feel comfortable with these operators.
