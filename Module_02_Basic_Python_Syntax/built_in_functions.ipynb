# %% [markdown]
# # Python Built-in Functions Overview
# This notebook covers commonly used built-in functions in Python: `print()`, `type()`, `str()`, `sorted()`, `max()`, and `min()`.
#
# **Note:** This content was generated by AI; review for accuracy.

# %% [markdown]
# ## `print()` – Display Output

# %%
month = "September"
print("Investigate failed login attempts during", month, "if more than", 100)

# %% [markdown]
# ## `type()` – Check Data Type

# %%
print(type(2))

# %% [markdown]
# ## `str()` – Convert to String

# %%
number = 12
string_representation = str(number)
print(string_representation)

# %% [markdown]
# ## `sorted()` – Sort an Iterable

# %%
time_list = [0,20,39,84,857,2970,1,3,48,58,930,94,207,6]
print(sorted(time_list))

# %%
time_list = [12, 2, 32, 19, 57, 22, 14]
print(sorted(time_list))
print(time_list)

# %% [markdown]
# ## `max()` and `min()` – Largest & Smallest Values

# %%
time_list = [12, 2, 32, 19, 57, 22, 14]
print(min(time_list))
print(max(time_list))
