# %% [markdown]
# <a href="https://colab.research.google.com/github/CrawDad-77/python-learning/blob/main/module1_intro/hello_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from Colab!")
# Out:
# Hello from Colab!

# %%
print("WOW! I did it!!")
# Out:
# WOW! I did it!!
