# %% [markdown]
# # Module 3 — For Loops and range()

# %%
for x in range(25):
    print(x)

# %%
friends = ['Taylor', 'Alex', 'Pat', 'Eli']
for friend in friends:
    print('Hi ' + friend)

# %%
for n in range(0, 11, 2):
    print(n)

# %%
for x in range(2, -2, -1):
    print(x)
